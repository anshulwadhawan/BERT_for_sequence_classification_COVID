# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/My Drive/Binary_Classification_COVID/Try2
# Out:
# /content/drive/My Drive/Binary_Classification_COVID/Try2

# %%
import pandas as pd
from tqdm import tqdm_notebook

dir = 'data/'

# %%
train_df = pd.read_csv(dir + 'train.tsv' ,sep="\t")
train_df.head()
# Out:
#                     Id  ...          Label
# 0  1241490299215634434  ...    INFORMATIVE
# 1  1245916400981381130  ...    INFORMATIVE
# 2  1241132432402849793  ...    INFORMATIVE
# 3  1236107253666607104  ...    INFORMATIVE
# 4  1239673817552879619  ...  UNINFORMATIVE
#
# [5 rows x 3 columns]

# %%
test_df = pd.read_csv(dir + 'valid.tsv',sep="\t", header = None)
test_df.head()
# Out:
#                      0  ...              2
# 0  1241728922192142336  ...  UNINFORMATIVE
# 1  1235713405992030209  ...    INFORMATIVE
# 2  1245941302367305728  ...  UNINFORMATIVE
# 3  1245913002840391681  ...  UNINFORMATIVE
# 4  1240543259299987457  ...  UNINFORMATIVE
#
# [5 rows x 3 columns]

# %%
train_df['Label'] = (train_df['Label'] == "INFORMATIVE").astype(int)
test_df[2] = (test_df[2] == "INFORMATIVE").astype(int)

# %%
test_df.head()
# Out:
#                      0                                                  1  2
# 0  1241728922192142336  For those saying Pakistan isn’t Italy; After 3...  0
# 1  1235713405992030209  Second case DR 🇩🇴 The Canadian woman has not b...  1
# 2  1245941302367305728  Kill Chain: the cyber war on America's electio...  0
# 3  1245913002840391681  Town hosts FIRST #Virtual #TownCouncil meeting...  0
# 4  1240543259299987457  Report suggested that the actual number of und...  0

# %%
train_df = pd.DataFrame({
    'id':range(len(train_df)),
    'label':train_df['Label'],
    'alpha':['a']*train_df.shape[0],
    'text': train_df['Text'].replace(r'\n', ' ', regex=True)
})

train_df.head()
# Out:
#    id  label alpha                                               text
# 0   0      1     a  Official death toll from #covid19 in the Unite...
# 1   1      1     a  Dearest Mr. President @USER 1,169 coronavirus ...
# 2   2      1     a  Latest Updates March 20 ⚠️5274 new cases and 3...
# 3   3      1     a  真把公主不当干部 BREAKING: 21 people on Grand Princess...
# 4   4      0     a  OKLAHOMA CITY — The State Department of Educat...

# %%
dev_df = pd.DataFrame({
    'id':range(len(test_df)),
    'label':test_df[2],
    'alpha':['a']*test_df.shape[0],
    'text': test_df[1].replace(r'\n', ' ', regex=True)
})

dev_df.head()
# Out:
#    id  label alpha                                               text
# 0   0      0     a  For those saying Pakistan isn’t Italy; After 3...
# 1   1      1     a  Second case DR 🇩🇴 The Canadian woman has not b...
# 2   2      0     a  Kill Chain: the cyber war on America's electio...
# 3   3      0     a  Town hosts FIRST #Virtual #TownCouncil meeting...
# 4   4      0     a  Report suggested that the actual number of und...

# %%
train_df.to_csv('data/train_processed.tsv', sep='\t', index=False, header=False, columns=train_df.columns)
dev_df.to_csv('data/valid_processed.tsv', sep='\t', index=False, header=False, columns=dev_df.columns)
